# %% [markdown]
# Аналитика по данным системы SKUD за период 3-4 квартал 2022 года

# %% [markdown]
# Импорт библиотек

# %%
import datetime as dt
import pandas as pd
import seaborn as sns # импорт библиотеки seaborn 
print(sns.__version__) # версия 
import matplotlib.pyplot as plt #модуль , отвечающий за визуализацию графиков 
# %matplotlib inline
# Out:
# 0.11.2

# %% [markdown]
# Считываем файл excel

# %%
data = pd.read_excel('3_4_kvartal.xlsx')
data.head() # вот что мы имеем
# Out:
#                  Date                   Object           Event  \
# 0 2022-07-01 07:49:00  ЦОД г. Усть-Каменогорск   Разрешен вход
# 1 2022-07-01 08:08:00  ЦОД г. Усть-Каменогорск   Разрешен вход
# 2 2022-07-01 08:20:00  ЦОД г. Усть-Каменогорск   Разрешен вход
# 3 2022-07-01 08:32:00  ЦОД г. Усть-Каменогорск  Разрешен выход
# 4 2022-07-01 08:35:00  ЦОД г. Усть-Каменогорск   Разрешен вход
#
#                Zone                               Employee
# 0  Центральный вход  Понамарёв Н. Н./ЕСЭДО/Главный инженер
# 1  Центральный вход               Сулейменов А. С./Охрана/
# 2  Центральный вход     Искакова М. М./СТО/Ведущий инженер
# 3  Центральный вход  Понамарёв Н. Н./ЕСЭДО/Главный инженер
# 4  Центральный вход            Баймолданова А./СТО/Инженер

# %% [markdown]
# Преобразуем тип столбца Date к типу Datetime

# %%
data['Date'] = pd.to_datetime(data['Date'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20386 entries, 0 to 20385
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      20386 non-null  datetime64[ns]
#  1   Object    20386 non-null  object
#  2   Event     20386 non-null  object
#  3   Zone      20386 non-null  object
#  4   Employee  20386 non-null  object
# dtypes: datetime64[ns](1), object(4)
# memory usage: 796.5+ KB

# %% [markdown]
# Преобразования типов данных, фильтрация

# %%
data['Day'] = data['Date'].dt.date # выделяем отдельно дату без времени
data = data[data['Zone']=='Центральный вход'] # Оставим события только по Центральному входу 
data = data[['Day', 'Date', 'Event', 'Employee']] # Оставим только нужны столбцы

data.head()
# Out:
#           Day                Date           Event  \
# 0  2022-07-01 2022-07-01 07:49:00   Разрешен вход
# 1  2022-07-01 2022-07-01 08:08:00   Разрешен вход
# 2  2022-07-01 2022-07-01 08:20:00   Разрешен вход
# 3  2022-07-01 2022-07-01 08:32:00  Разрешен выход
# 4  2022-07-01 2022-07-01 08:35:00   Разрешен вход
#
#                                 Employee
# 0  Понамарёв Н. Н./ЕСЭДО/Главный инженер
# 1               Сулейменов А. С./Охрана/
# 2     Искакова М. М./СТО/Ведущий инженер
# 3  Понамарёв Н. Н./ЕСЭДО/Главный инженер
# 4            Баймолданова А./СТО/Инженер

# %% [markdown]
# Функция для обрезки лишней информации после ФИО, так как должности менялись и фамилии повторяются, также уберем опечатку по фамилии Скиданов

# %%
def cut_fio(fio):
    fio = fio.replace('Сиданов А.', 'Скиданов А.')
    t = fio.find('.')
    return fio[:t+1]

data['Employee'] = data['Employee'].apply(cut_fio)   
data.head()
# Out:
#           Day                Date           Event         Employee
# 0  2022-07-01 2022-07-01 07:49:00   Разрешен вход     Понамарёв Н.
# 1  2022-07-01 2022-07-01 08:08:00   Разрешен вход    Сулейменов А.
# 2  2022-07-01 2022-07-01 08:20:00   Разрешен вход      Искакова М.
# 3  2022-07-01 2022-07-01 08:32:00  Разрешен выход     Понамарёв Н.
# 4  2022-07-01 2022-07-01 08:35:00   Разрешен вход  Баймолданова А.

# %% [markdown]
# функция для формирования мини таблицы для каждого юзера за 1 день, где вход и выход сгруппированы и посчитан промежуток нахождения в офисе

# %%
def create_tdelta_df(current_date, user_fio): # функция для формирования мини таблицы для каждого юзера за 1 день, где вход и выход сгруппированы и посчитан промежуток нахождения в офисе 
    user_tdelta_df = data[(data['Employee'] == user_fio )&(data['Day'] == current_date)]
    if user_tdelta_df.empty:
        return user_tdelta_df
    else:
        user_enters = user_tdelta_df[user_tdelta_df['Event'] == 'Разрешен вход']
        user_enters = user_enters[['Date', 'Employee', 'Day']].rename(columns={"Date": "Enter_time"})
        user_exits = user_tdelta_df[user_tdelta_df['Event'] == 'Разрешен выход']
        user_exits = user_exits[['Date', 'Employee', 'Day']].rename(columns={"Date": "Exit_time"})
        k = 1
        for index, row in user_enters.iterrows():
            user_enters.loc[index,'N_enter'] =  k
            k += 1   
        r = 1
        for index, row in user_exits.iterrows():
            user_exits.loc[index,'N_enter'] =  r
            r += 1 
        user_tdelta_df = user_enters.merge(        # объединяем датафреймы по полю N_enter 
        user_exits, on="N_enter", how="inner"
        )
        user_tdelta_df = user_tdelta_df[['Day_x', 'Employee_x', 'N_enter', 'Enter_time', 'Exit_time']].rename(columns={'Day_x': 'Day', 'Employee_x': 'Employee'})
        user_tdelta_df['Timedelta'] = user_tdelta_df['Exit_time'] - user_tdelta_df['Enter_time']
        return user_tdelta_df

# %% [markdown]
# Формируем пустой DataFrame для дальнейшего заполнения

# %%
tdelta_df = pd.DataFrame({'Day': [],
                     'Employee': [],
                     'N_enter': [],
                     'Enter_time': [],
                     'Exit_time': [],
                     'Timedelta': [],
                     'Lunch_tdelta':[]
                     })
test_tdelta = create_tdelta_df(dt.date(2022, 7, 25), 'Абылканова А.') # проба функции
test_tdelta
# Out:
#           Day       Employee  N_enter          Enter_time           Exit_time  \
# 0  2022-07-25  Абылканова А.      1.0 2022-07-25 09:56:00 2022-07-25 18:07:00
#
#         Timedelta
# 0 0 days 08:11:00

# %%
test_date = dt.date(2022, 7, 25)
yyyy = test_date.year
mm = test_date.month
dd = test_date.day
lunch_time_start = dt.datetime(yyyy, mm, dd, 13, 0, 0)
lunch_time_end = dt.datetime(yyyy, mm, dd, 14, 0, 0)
lunch_time_start
# Out:
# datetime.datetime(2022, 7, 25, 13, 0)

# %%
enter_time = test_tdelta.loc[0, 'Enter_time']
enter_time = enter_time
print(enter_time)
lunch_time_start < enter_time < lunch_time_end
# Out:
# 2022-07-25 09:56:00
# False

# %%
for index, row in test_tdelta.iterrows():
    enter_time = test_tdelta.loc[index,'Enter_time']
    exit_time = test_tdelta.loc[index,'Exit_time']
    #print(f'Enter time: {enter_time}  Exit time: {exit_time}')

    if (lunch_time_start <= enter_time <= lunch_time_end) and  (lunch_time_start <= exit_time <= lunch_time_end):
        test_tdelta.loc[index,'Lunch_tdelta'] = exit_time - enter_time
    elif (lunch_time_start <= enter_time <= lunch_time_end) and not(lunch_time_start <= exit_time <= lunch_time_end):
        test_tdelta.loc[index,'Lunch_tdelta'] = lunch_time_end - enter_time
    elif not(lunch_time_start <= enter_time <= lunch_time_end) and (lunch_time_start <= exit_time <= lunch_time_end):
        test_tdelta.loc[index,'Lunch_tdelta'] = exit_time - lunch_time_start
    elif enter_time < lunch_time_start and exit_time > lunch_time_end:
        test_tdelta.loc[index,'Lunch_tdelta'] = dt.timedelta(hours=1)
    else:
        test_tdelta.loc[index,'Lunch_tdelta'] = dt.timedelta(0, 0)
test_tdelta
# Out:
#           Day       Employee  N_enter          Enter_time           Exit_time  \
# 0  2022-07-25  Абылканова А.      1.0 2022-07-25 09:56:00 2022-07-25 18:07:00
#
#         Timedelta Lunch_tdelta
# 0 0 days 08:11:00       0 days

# %% [markdown]
# Формируем списки дат событий и списки сотрудников для дальнейшего формирования нового Датафрейма

# %%
dates = sorted(data['Day'].unique().tolist())
print(dates)
users = data['Employee'].unique().tolist()
# исключаем из списка бывших сотрудников, водителей, охранников 
users = [user for user in users if user not in ['Исаков М.', 'Андреев О.', 'Скиданов А.', 'Сулейменов А.', 'Искакова М.', 'Икамбаева С.', 'Кенесбек Е.', 'Федорова Л.', 'Мезенцев А.', 'Энгель Г.']]
print(users)
# Out:
# [datetime.date(2022, 7, 1), datetime.date(2022, 7, 4), datetime.date(2022, 7, 5), datetime.date(2022, 7, 7), datetime.date(2022, 7, 8), datetime.date(2022, 7, 11), datetime.date(2022, 7, 12), datetime.date(2022, 7, 13), datetime.date(2022, 7, 14), datetime.date(2022, 7, 15), datetime.date(2022, 7, 18), datetime.date(2022, 7, 19), datetime.date(2022, 7, 20), datetime.date(2022, 7, 21), datetime.date(2022, 7, 22), datetime.date(2022, 7, 23), datetime.date(2022, 7, 25), datetime.date(2022, 7, 26), datetime.date(2022, 7, 27), datetime.date(2022, 7, 28), datetime.date(2022, 7, 29), datetime.date(2022, 8, 1), datetime.date(2022, 8, 2), datetime.date(2022, 8, 3), datetime.date(2022, 8, 4), datetime.date(2022, 8, 5), datetime.date(2022, 8, 8), datetime.date(2022, 8, 9), datetime.date(2022, 8, 10), datetime.date(2022, 8, 11), datetime.date(2022, 8, 12), datetime.date(2022, 8, 15), datetime.date(2022, 8, 16), datetime.date(2022, 8, 17), datetime.date(2022, 8, 18), datetime.date(2022, 8, 19), datetime.date(2022, 8, 22), datetime.date(2022, 8, 23), datetime.date(2022, 8, 24), datetime.date(2022, 8, 25), datetime.date(2022, 8, 26), datetime.date(2022, 8, 27), datetime.date(2022, 8, 30), datetime.date(2022, 8, 31), datetime.date(2022, 9, 1), datetime.date(2022, 9, 2), datetime.date(2022, 9, 5), datetime.date(2022, 9, 6), datetime.date(2022, 9, 7), datetime.date(2022, 9, 8), datetime.date(2022, 9, 9), datetime.date(2022, 9, 12), datetime.date(2022, 9, 13), datetime.date(2022, 9, 14), datetime.date(2022, 9, 15), datetime.date(2022, 9, 16), datetime.date(2022, 9, 19), datetime.date(2022, 9, 20), datetime.date(2022, 9, 21), datetime.date(2022, 9, 22), datetime.date(2022, 9, 23), datetime.date(2022, 9, 26), datetime.date(2022, 9, 27), datetime.date(2022, 9, 28), datetime.date(2022, 9, 29), datetime.date(2022, 9, 30), datetime.date(2022, 10, 3), datetime.date(2022, 10, 4), datetime.date(2022, 10, 5), datetime.date(2022, 10, 6), datetime.date(2022, 10, 7), datetime.date(2022, 10, 10), datetime.date(2022, 10, 11), datetime.date(2022, 10, 12), datetime.date(2022, 10, 13), datetime.date(2022, 10, 14), datetime.date(2022, 10, 17), datetime.date(2022, 10, 18), datetime.date(2022, 10, 19), datetime.date(2022, 10, 20), datetime.date(2022, 10, 21), datetime.date(2022, 10, 22), datetime.date(2022, 10, 26), datetime.date(2022, 10, 27), datetime.date(2022, 10, 28), datetime.date(2022, 10, 31), datetime.date(2022, 11, 1), datetime.date(2022, 11, 2), datetime.date(2022, 11, 3), datetime.date(2022, 11, 4), datetime.date(2022, 11, 6), datetime.date(2022, 11, 7), datetime.date(2022, 11, 8), datetime.date(2022, 11, 9), datetime.date(2022, 11, 10), datetime.date(2022, 11, 11), datetime.date(2022, 11, 14), datetime.date(2022, 11, 15), datetime.date(2022, 11, 16), datetime.date(2022, 11, 17), datetime.date(2022, 11, 18), datetime.date(2022, 11, 21), datetime.date(2022, 11, 22), datetime.date(2022, 11, 23), datetime.date(2022, 11, 24), datetime.date(2022, 11, 25), datetime.date(2022, 11, 28), datetime.date(2022, 11, 29), datetime.date(2022, 11, 30), datetime.date(2022, 12, 1), datetime.date(2022, 12, 2), datetime.date(2022, 12, 5), datetime.date(2022, 12, 6), datetime.date(2022, 12, 7), datetime.date(2022, 12, 8), datetime.date(2022, 12, 9), datetime.date(2022, 12, 12), datetime.date(2022, 12, 13), datetime.date(2022, 12, 14)]
# ['Понамарёв Н.', 'Баймолданова А.', 'Камбарова М.', 'Садыков А.', 'Путейчев В.', 'Кузнецов И.', 'Звонов А.', 'Бондарчук Б.', 'Мурумбаева Г.', 'Пинегин Е.', 'Калабухов А.', 'Миллер Л.', 'Рулёва Е.', 'Рулёв А.', 'Булыгин Н.', 'Серегин Д.', 'Даутова С.', 'Медведев И.', 'Ляпунова Н.', 'Имамбаев М.', 'Мусин С.', 'Хальников О.', 'Баженов Е.', 'Сейтказин С.', 'Радичев С.', 'Сохин А.', 'Абылканова А.', 'Олейник Д.', 'Плехов А.', 'Хохлов Р.', 'Печенкин Р.', 'Григорьев И.', 'Зацепин Д.', 'Галлямов А.', 'Есенжарулы Д.', 'Тотаева А.', 'Болатбек Е.', 'Акежанова А.', 'Овсейчук И.', 'Адамбеков Е.', 'Максимович Е.', 'Махсутов А.', 'Хижняк П.', 'Огневая А.', 'Никишина Л.', 'Нурбеков К.']

# %%
for date in dates: # формируем новую таблицу с временными промежутками 
    for user in users:
        df = create_tdelta_df(date, user)
        if df.empty:
            continue
        else:
            yyyy = date.year #выделяем год из взятой даты
            mm = date.month #выделяем месяц
            dd = date.day #выделяем день
            lunch_time_start = dt.datetime(yyyy, mm, dd, 13, 0, 0) # собираем датувремя начала обеденного перерыва на текущий день 
            lunch_time_end = dt.datetime(yyyy, mm, dd, 14, 0, 0) # собираем датувремя конца обеденного перерыва
            for index, row in df.iterrows(): #Проходимся по всем промежуткам времени  
                enter_time = df.loc[index,'Enter_time'] # время входа 
                exit_time = df.loc[index,'Exit_time'] # время выхода 
                #print(f'Enter time: {enter_time}  Exit time: {exit_time}')
                # если время входа ВО время обед-го перерыва           и    время выхода ВО время обед перерыва
                if (lunch_time_start <= enter_time <= lunch_time_end) and  (lunch_time_start <= exit_time <= lunch_time_end):
                    df.loc[index,'Lunch_tdelta'] = exit_time - enter_time # то этот промежуток времени относим полдностью к lunch_time
                  # если время входа ВО время обед-го перерыва   и    время выхода НЕ во время обед перерыва
                elif (lunch_time_start <= enter_time <= lunch_time_end) and not(lunch_time_start <= exit_time <= lunch_time_end):
                    df.loc[index,'Lunch_tdelta'] = lunch_time_end - enter_time # то lunch_time считаем так 
                   # если время входа НЕ во время обед-го перерыва   и    время выхода ВО время обед перерыва  
                elif not(lunch_time_start <= enter_time <= lunch_time_end) and (lunch_time_start <= exit_time <= lunch_time_end):
                    df.loc[index,'Lunch_tdelta'] = exit_time - lunch_time_start 
                    # если время входа ДО обед-го перерыва   и    время выхода ПОСЛЕ обед перерыва  
                elif enter_time <= lunch_time_start and exit_time >= lunch_time_end:
                    df.loc[index,'Lunch_tdelta'] = dt.timedelta(0, hours = 1) # то в lunch_time записываем 1 час 
                else:
                    df.loc[index,'Lunch_tdelta'] = dt.timedelta(0) # во всех остальных случаях записываем 0 в lunch_time



            tdelta_df = pd.concat([tdelta_df, df], sort=False, axis=0) # приклеиваем эту таблицу к tdelta_df
    
tdelta_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8477 entries, 0 to 2
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Day           8477 non-null   object
#  1   Employee      8477 non-null   object
#  2   N_enter       8477 non-null   float64
#  3   Enter_time    8477 non-null   object
#  4   Exit_time     8477 non-null   object
#  5   Timedelta     8477 non-null   object
#  6   Lunch_tdelta  8477 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 529.8+ KB

# %%
dt.timedelta(0, hours=1)
# Out:
# datetime.timedelta(seconds=3600)

# %%
tdelta_df.head()
# Out:
#           Day      Employee  N_enter           Enter_time  \
# 0  2022-07-01  Понамарёв Н.      1.0  2022-07-01 07:49:00
# 1  2022-07-01  Понамарёв Н.      2.0  2022-07-01 08:43:00
# 2  2022-07-01  Понамарёв Н.      3.0  2022-07-01 10:04:00
# 3  2022-07-01  Понамарёв Н.      4.0  2022-07-01 10:39:00
# 4  2022-07-01  Понамарёв Н.      5.0  2022-07-01 11:29:00
#
#              Exit_time        Timedelta     Lunch_tdelta
# 0  2022-07-01 08:32:00  0 days 00:43:00  0 days 00:00:00
# 1  2022-07-01 09:58:00  0 days 01:15:00  0 days 00:00:00
# 2  2022-07-01 10:30:00  0 days 00:26:00  0 days 00:00:00
# 3  2022-07-01 11:23:00  0 days 00:44:00  0 days 00:00:00
# 4  2022-07-01 12:20:00  0 days 00:51:00  0 days 00:00:00

# %%
tdelta_df['Day'] = pd.to_datetime(tdelta_df['Day'])
tdelta_df['Day'] = tdelta_df['Day'].dt.date
tdelta_df['Enter_time'] = pd.to_datetime(tdelta_df['Enter_time'])
tdelta_df['Exit_time'] = pd.to_datetime(tdelta_df['Exit_time'])
tdelta_df['Timedelta'] = pd.to_timedelta(tdelta_df['Timedelta'])
tdelta_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8477 entries, 0 to 2
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Day           8477 non-null   object
#  1   Employee      8477 non-null   object
#  2   N_enter       8477 non-null   float64
#  3   Enter_time    8477 non-null   datetime64[ns]
#  4   Exit_time     8477 non-null   datetime64[ns]
#  5   Timedelta     8477 non-null   timedelta64[ns]
#  6   Lunch_tdelta  8477 non-null   object
# dtypes: datetime64[ns](2), float64(1), object(3), timedelta64[ns](1)
# memory usage: 529.8+ KB

# %%
wrong = tdelta_df[tdelta_df['Timedelta'] < dt.timedelta(0)] #Проверка на ошибки 
wrong['Employee'].unique()
# Out:
# array([], dtype=object)

# %%
tdelta_df.reset_index()
tdelta_df.head(10)
# Out:
#           Day      Employee  N_enter          Enter_time           Exit_time  \
# 0  2022-07-01  Понамарёв Н.      1.0 2022-07-01 07:49:00 2022-07-01 08:32:00
# 1  2022-07-01  Понамарёв Н.      2.0 2022-07-01 08:43:00 2022-07-01 09:58:00
# 2  2022-07-01  Понамарёв Н.      3.0 2022-07-01 10:04:00 2022-07-01 10:30:00
# 3  2022-07-01  Понамарёв Н.      4.0 2022-07-01 10:39:00 2022-07-01 11:23:00
# 4  2022-07-01  Понамарёв Н.      5.0 2022-07-01 11:29:00 2022-07-01 12:20:00
# 5  2022-07-01  Понамарёв Н.      6.0 2022-07-01 12:26:00 2022-07-01 12:47:00
# 6  2022-07-01  Понамарёв Н.      7.0 2022-07-01 12:53:00 2022-07-01 13:06:00
# 7  2022-07-01  Понамарёв Н.      8.0 2022-07-01 13:14:00 2022-07-01 13:40:00
# 8  2022-07-01  Понамарёв Н.      9.0 2022-07-01 13:48:00 2022-07-01 14:12:00
# 9  2022-07-01  Понамарёв Н.     10.0 2022-07-01 14:22:00 2022-07-01 15:13:00
#
#         Timedelta     Lunch_tdelta
# 0 0 days 00:43:00  0 days 00:00:00
# 1 0 days 01:15:00  0 days 00:00:00
# 2 0 days 00:26:00  0 days 00:00:00
# 3 0 days 00:44:00  0 days 00:00:00
# 4 0 days 00:51:00  0 days 00:00:00
# 5 0 days 00:21:00  0 days 00:00:00
# 6 0 days 00:13:00  0 days 00:06:00
# 7 0 days 00:26:00  0 days 00:26:00
# 8 0 days 00:24:00  0 days 00:12:00
# 9 0 days 00:51:00  0 days 00:00:00

# %%
hours_df = tdelta_df[(tdelta_df['Employee'] == 'Даутова С.') & (tdelta_df['Day'] == dt.date(2022,7,5))] # проверяем как фильтруются данные 
hours_df.head()
# Out:
#           Day    Employee  N_enter          Enter_time           Exit_time  \
# 0  2022-07-05  Даутова С.      1.0 2022-07-05 09:00:00 2022-07-05 13:04:00
# 1  2022-07-05  Даутова С.      2.0 2022-07-05 13:11:00 2022-07-05 13:34:00
# 2  2022-07-05  Даутова С.      3.0 2022-07-05 14:09:00 2022-07-05 17:35:00
#
#         Timedelta     Lunch_tdelta
# 0 0 days 04:04:00  0 days 00:04:00
# 1 0 days 00:23:00  0 days 00:23:00
# 2 0 days 03:26:00  0 days 00:00:00

# %%
early_exit = dt.datetime(2022, 7, 5, 18, 0, 0) - hours_df[hours_df['N_enter']==hours_df['N_enter'].max()]['Exit_time'] #пробуем вычислить ранний уход с рабочего места 
early_exit[hours_df['N_enter'].max()-1]
# Out:
# Timedelta('0 days 00:25:00')

# %%
hours_df['N_enter'].max()
# Out:
# 3.0

# %%
print(users)
# Out:
# ['Понамарёв Н.', 'Баймолданова А.', 'Камбарова М.', 'Садыков А.', 'Путейчев В.', 'Кузнецов И.', 'Звонов А.', 'Бондарчук Б.', 'Мурумбаева Г.', 'Пинегин Е.', 'Калабухов А.', 'Миллер Л.', 'Рулёва Е.', 'Рулёв А.', 'Булыгин Н.', 'Серегин Д.', 'Даутова С.', 'Медведев И.', 'Ляпунова Н.', 'Имамбаев М.', 'Мусин С.', 'Хальников О.', 'Баженов Е.', 'Сейтказин С.', 'Радичев С.', 'Сохин А.', 'Абылканова А.', 'Олейник Д.', 'Плехов А.', 'Хохлов Р.', 'Печенкин Р.', 'Григорьев И.', 'Зацепин Д.', 'Галлямов А.', 'Есенжарулы Д.', 'Тотаева А.', 'Болатбек Е.', 'Акежанова А.', 'Овсейчук И.', 'Адамбеков Е.', 'Максимович Е.', 'Махсутов А.', 'Хижняк П.', 'Огневая А.', 'Никишина Л.', 'Нурбеков К.']

# %%
def summ_hours_df(current_date, user_fio): # функция для формирования кортежа с суммой часов проведенных в офисе 
    hours_df = tdelta_df[(tdelta_df['Employee'] == user_fio) & (tdelta_df['Day'] == current_date)]
    per_day = tuple()
   
    if hours_df.empty:
        return per_day
    else:
        first_enter_time = hours_df[hours_df['N_enter']==1.0]['Enter_time']
        yyyy = current_date.year
        mm = current_date.month
        dd = current_date.day
        last = hours_df['N_enter'].max()
        last_exit_time = hours_df[hours_df['N_enter']==last]['Exit_time']
        last_exit_time = last_exit_time[round(last-1)]

        if user_fio == 'Баженов Е.':
            late_time = first_enter_time - dt.datetime(yyyy, mm, dd, 10, 0, 0)
            early_exit = dt.datetime(yyyy, mm, dd, 19, 0, 0) - last_exit_time
        elif user_fio == 'Камбарова М.':
            late_time = first_enter_time - dt.datetime(yyyy, mm, dd, 8, 30, 0)
            early_exit = dt.datetime(yyyy, mm, dd, 17, 30, 0) - last_exit_time
        else:    
            late_time = first_enter_time - dt.datetime(yyyy, mm, dd, 9, 0, 0)
            early_exit = dt.datetime(yyyy, mm, dd, 18, 0, 0) - last_exit_time

        #early_exit = early_exit[last-1]
        tdelta = hours_df.groupby(by='Day')['Timedelta'].agg('sum')
        lunch_tdelta = hours_df.groupby(by='Day')['Lunch_tdelta'].agg('sum')
        c = user_fio.find(' ')

        if user_fio[c-1] in ['а', 'я', 'р']: #если фамилия заканчивается на -а, -я, -р , то в переменную sex записываем Жен, иначе Муж
            gender = 'Female'
        else:
            gender = 'Male'
                                                                                                                    #отнимаем обед время от общего времени нахождения в офисе 
        per_day = (current_date, user_fio, gender, first_enter_time[0], last_exit_time, late_time[0], early_exit, last, tdelta[current_date]- lunch_tdelta[current_date])
        return per_day

# %%
hours_list = [] 
for date in dates:
    for user in users:
        tpl = summ_hours_df(date, user)
        if tpl:
            hours_list.append(tpl)
            #hours_list
        else:
            continue

# %%
# Формируем новую таблицу на базе списка с кортежами
hours_df = pd.DataFrame(hours_list, columns=['Day', 'Employee', 'Gender', 'First_enter_time', 'Last_exit_time', 'Late_time', 'Early_exit', 'Exit_cnt', 'Timedelta']) 
hours_df.head(10)
# Out:
#           Day         Employee  Gender    First_enter_time  \
# 0  2022-07-01     Понамарёв Н.    Male 2022-07-01 07:49:00
# 1  2022-07-01  Баймолданова А.  Female 2022-07-01 08:35:00
# 2  2022-07-01     Камбарова М.  Female 2022-07-01 08:39:00
# 3  2022-07-01       Садыков А.    Male 2022-07-01 08:43:00
# 4  2022-07-01      Путейчев В.    Male 2022-07-01 08:48:00
# 5  2022-07-01      Кузнецов И.    Male 2022-07-01 08:53:00
# 6  2022-07-01        Звонов А.    Male 2022-07-01 08:54:00
# 7  2022-07-01     Бондарчук Б.    Male 2022-07-01 08:54:00
# 8  2022-07-01    Мурумбаева Г.  Female 2022-07-01 08:55:00
# 9  2022-07-01       Пинегин Е.    Male 2022-07-01 08:56:00
#
#        Last_exit_time         Late_time        Early_exit  Exit_cnt  \
# 0 2022-07-01 18:12:00 -1 days +22:49:00 -1 days +23:48:00      14.0
# 1 2022-07-01 18:07:00 -1 days +23:35:00 -1 days +23:53:00       3.0
# 2 2022-07-01 17:37:00   0 days 00:09:00 -1 days +23:53:00       2.0
# 3 2022-07-01 18:16:00 -1 days +23:43:00 -1 days +23:44:00       3.0
# 4 2022-07-01 18:09:00 -1 days +23:48:00 -1 days +23:51:00       2.0
# 5 2022-07-01 17:08:00 -1 days +23:53:00   0 days 00:52:00       2.0
# 6 2022-07-01 18:45:00 -1 days +23:54:00 -1 days +23:15:00       2.0
# 7 2022-07-01 18:18:00 -1 days +23:54:00 -1 days +23:42:00       3.0
# 8 2022-07-01 18:09:00 -1 days +23:55:00 -1 days +23:51:00       2.0
# 9 2022-07-01 18:06:00 -1 days +23:56:00 -1 days +23:54:00       1.0
#
#         Timedelta
# 0 0 days 07:57:00
# 1 0 days 08:18:00
# 2 0 days 07:41:00
# 3 0 days 08:17:00
# 4 0 days 08:21:00
# 5 0 days 07:15:00
# 6 0 days 08:19:00
# 7 0 days 07:28:00
# 8 0 days 07:59:00
# 9 0 days 08:10:00

# %%
hours_df['Late_time'] = hours_df[(dt.timedelta(hours=0) < hours_df['Late_time']) & (hours_df['Late_time']< dt.timedelta(minutes=31))]['Late_time'] #Оставим только положительные значения до 30 мин 
hours_df['Early_exit'] = hours_df[(dt.timedelta(hours=0) < hours_df['Early_exit']) & (hours_df['Early_exit'] < dt.timedelta(minutes=31))]['Early_exit'] #Оставим только положительные значения до 30 мин 
hours_df['Day'] = pd.to_datetime(hours_df['Day']) # приводим к типу
hours_df['Month'] = hours_df['Day'].dt.month # добавим столбец с месяцем 
hours_df[hours_df['Late_time'].notnull()]
# Out:
#             Day      Employee  Gender    First_enter_time      Last_exit_time  \
# 2    2022-07-01  Камбарова М.  Female 2022-07-01 08:39:00 2022-07-01 17:37:00
# 15   2022-07-01    Серегин Д.    Male 2022-07-01 09:01:00 2022-07-01 18:06:00
# 17   2022-07-01   Медведев И.    Male 2022-07-01 09:06:00 2022-07-01 11:52:00
# 18   2022-07-01   Ляпунова Н.  Female 2022-07-01 09:07:00 2022-07-01 18:11:00
# 19   2022-07-01   Имамбаев М.    Male 2022-07-01 09:07:00 2022-07-01 18:06:00
# ...         ...           ...     ...                 ...                 ...
# 2881 2022-12-14    Баженов Е.    Male 2022-12-14 10:28:00 2022-12-14 19:20:00
# 2882 2022-12-14    Радичев С.    Male 2022-12-14 09:03:00 2022-12-14 13:06:00
# 2885 2022-12-14    Тотаева А.  Female 2022-12-14 09:08:00 2022-12-14 18:02:00
# 2887 2022-12-14   Овсейчук И.    Male 2022-12-14 09:04:00 2022-12-14 18:16:00
# 2888 2022-12-14  Адамбеков Е.    Male 2022-12-14 09:11:00 2022-12-14 10:10:00
#
#            Late_time Early_exit  Exit_cnt       Timedelta  Month
# 2    0 days 00:09:00        NaT       2.0 0 days 07:41:00      7
# 15   0 days 00:01:00        NaT       2.0 0 days 07:37:00      7
# 17   0 days 00:06:00        NaT       2.0 0 days 02:40:00      7
# 18   0 days 00:07:00        NaT       2.0 0 days 08:04:00      7
# 19   0 days 00:07:00        NaT       4.0 0 days 07:25:00      7
# ...              ...        ...       ...             ...    ...
# 2881 0 days 00:28:00        NaT      14.0 0 days 06:23:00     12
# 2882 0 days 00:03:00        NaT       1.0 0 days 03:57:00     12
# 2885 0 days 00:08:00        NaT       2.0 0 days 07:54:00     12
# 2887 0 days 00:04:00        NaT       2.0 0 days 08:12:00     12
# 2888 0 days 00:11:00        NaT       1.0 0 days 00:59:00     12
#
# [1008 rows x 10 columns]

# %%
hours_df['First_enter_time'] = hours_df['First_enter_time'].dt.time # 
hours_df['Last_exit_time'] = hours_df['Last_exit_time'].dt.time
hours_df.head()
# Out:
#          Day         Employee  Gender First_enter_time Last_exit_time  \
# 0 2022-07-01     Понамарёв Н.    Male         07:49:00       18:12:00
# 1 2022-07-01  Баймолданова А.  Female         08:35:00       18:07:00
# 2 2022-07-01     Камбарова М.  Female         08:39:00       17:37:00
# 3 2022-07-01       Садыков А.    Male         08:43:00       18:16:00
# 4 2022-07-01      Путейчев В.    Male         08:48:00       18:09:00
#
#         Late_time Early_exit  Exit_cnt       Timedelta  Month
# 0             NaT        NaT      14.0 0 days 07:57:00      7
# 1             NaT        NaT       3.0 0 days 08:18:00      7
# 2 0 days 00:09:00        NaT       2.0 0 days 07:41:00      7
# 3             NaT        NaT       3.0 0 days 08:17:00      7
# 4             NaT        NaT       2.0 0 days 08:21:00      7

# %%
hours_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2890 entries, 0 to 2889
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Day               2890 non-null   datetime64[ns]
#  1   Employee          2890 non-null   object
#  2   Gender            2890 non-null   object
#  3   First_enter_time  2890 non-null   object
#  4   Last_exit_time    2890 non-null   object
#  5   Late_time         1008 non-null   timedelta64[ns]
#  6   Early_exit        157 non-null    timedelta64[ns]
#  7   Exit_cnt          2890 non-null   float64
#  8   Timedelta         2890 non-null   timedelta64[ns]
#  9   Month             2890 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(4), timedelta64[ns](3)
# memory usage: 225.9+ KB

# %% [markdown]
# Переводим значения Timedelta в float - числовые, для возможности построения графиков

# %%
hours_df['Late_time'] = hours_df['Late_time'].apply(lambda x: x.total_seconds()/60) # переводим timedelta в int - минуты 
hours_df['Early_exit'] = hours_df['Early_exit'].apply(lambda x: x.total_seconds()/60) 
hours_df['Timedelta'] = hours_df['Timedelta'].apply(lambda x: round(x.total_seconds()/3600, 2)) # переводим timedelta в int - часы 
hours_df = hours_df.rename(columns={'Late_time': 'Late_min', 'Timedelta': 'Timedelta_hour'})
hours_df = hours_df.fillna(0)
hours_df.head()
# Out:
#          Day         Employee  Gender First_enter_time Last_exit_time  \
# 0 2022-07-01     Понамарёв Н.    Male         07:49:00       18:12:00
# 1 2022-07-01  Баймолданова А.  Female         08:35:00       18:07:00
# 2 2022-07-01     Камбарова М.  Female         08:39:00       17:37:00
# 3 2022-07-01       Садыков А.    Male         08:43:00       18:16:00
# 4 2022-07-01      Путейчев В.    Male         08:48:00       18:09:00
#
#    Late_min  Early_exit  Exit_cnt  Timedelta_hour  Month
# 0       0.0         0.0      14.0            7.95      7
# 1       0.0         0.0       3.0            8.30      7
# 2       9.0         0.0       2.0            7.68      7
# 3       0.0         0.0       3.0            8.28      7
# 4       0.0         0.0       2.0            8.35      7

# %% [markdown]
# Выявляем работников с опозданиями более 10 мин, сортируем по убыванию значения и на основе расчетов строим график

# %%
laters = hours_df[hours_df['Late_min']>5][['Employee', 'Late_min']].groupby(by='Employee').agg('count').sort_values(by='Late_min', ascending=False)

# %%
fig = plt.figure(figsize=(20, 10))
barplot = sns.barplot(
    data=laters,
    y='Late_min',
    x=laters.index   
)
barplot.set_title('Количество опозданий сотрудников в первой половине дня');
barplot.set_xlabel('Сотрудник');
barplot.set_ylabel('Количество');
plt.xticks(rotation = 45)
barplot.grid()

# %%
local_users = [user for user in users if user not in ['Нурбеков К.', 'Хохлов Р.', 'Печенкин Р.', 'Махсутов А.', 'Плехов А.', 'Болатбек Е.', 'Хижняк П.', 'Григорьев И.', 'Зацепин Д.', 'Галлямов А.', 'Максимович Е.', 'Никишина Л.']]
mean_late = hours_df[(hours_df['Employee'].isin(local_users))][['Employee', 'Late_min']].groupby(by='Employee').agg('mean').sort_values(by='Late_min', ascending=False)

# %%
fig = plt.figure(figsize=(10, 20))
barplot = sns.barplot(
    data=hours_df,
    y='Employee',
    x='Late_min',
    orient='h',
    order = mean_late.index
    #width=0.9
)
barplot.set_title('Среднее время опоздания');
barplot.set_xlabel('Время');
barplot.set_ylabel('Сотрудник');
barplot.grid()

# %% [markdown]
# Выявим сотрудников злоупотребляющих ранним уходом с рабочего места , для этого отсортируем по убыванию количества случаев раннего ухода  и на основе расчета построим barplot

# %%
earliers = hours_df[hours_df['Early_exit']>0][['Employee', 'Early_exit']].groupby(by='Employee').agg('count').sort_values(by='Early_exit', ascending=False)

# %%
fig = plt.figure(figsize=(20, 7))
barplot = sns.barplot(
    data = earliers,
    y ='Early_exit',
    x =earliers.index   
)
barplot.set_title('Количество ранних уходов с рабочего места');
barplot.set_xlabel('Сотрудник');
barplot.set_ylabel('Количество');
plt.xticks(rotation = 45)
barplot.grid()

# %% [markdown]
# Построим коробочковую диаграмму для определения статистики по времени нахождения в офисе каждого сотрудника

# %%
fig = plt.figure(figsize=(25, 7))
boxplot = sns.boxplot(
    data=hours_df,
    x='Employee',
    y='Timedelta_hour',
    #orient='h',
    hue='Gender'
)
boxplot.set_title('Время нахождения в офисе');
boxplot.set_xlabel('Время, часы');
boxplot.set_ylabel('Сотрудник');
plt.xticks(rotation = 90)
boxplot.grid()

# %% [markdown]
# Построим barplot для определения среднего времени проведенного в офисе отдельно для местных сотрудников

# %%
local_users = [user for user in users if user not in ['Нурбеков К.', 'Хохлов Р.', 'Печенкин Р.', 'Махсутов А.', 'Плехов А.', 'Болатбек Е.', 'Хижняк П.', 'Григорьев И.', 'Зацепин Д.', 'Галлямов А.', 'Максимович Е.', 'Никишина Л.']]

# %%
local_hours = hours_df[hours_df['Employee'].isin(local_users)][['Employee', 'Timedelta_hour']].groupby(by='Employee').agg('mean').sort_values(by='Timedelta_hour')

# %%
fig = plt.figure(figsize=(20, 7))
boxplot = sns.barplot(
    data=local_hours,
    y='Timedelta_hour',
    x=local_hours.index
    #order=local_hours.sort_values('Timedelta_hour', ascending=False).Staff,
    #hue='Gender'
    #width=0.9
)
boxplot.set_title('Среднее время нахождения в офисе (местные сотрудники)');
boxplot.set_xlabel('Сотрудники');
boxplot.set_ylabel('Время');
plt.xticks(rotation=90)
boxplot.grid()

# %% [markdown]
# Выявим сотрудников часто покидающих рабочее место

# %%
result = hours_df[hours_df['Employee'].isin(local_users)][['Employee','Exit_cnt']].groupby(by='Employee').agg('mean').sort_values(by='Exit_cnt', ascending=False)

# %%
fig = plt.figure(figsize=(20, 7))
boxplot = sns.barplot(
    data= hours_df[hours_df['Employee'].isin(local_users)],
    y='Exit_cnt',
    x='Employee',
    order= result.index#,
    #hue='Gender'

)
boxplot.set_title('Среднее количество входов-выходов из офиса');
boxplot.set_xlabel('Сотрудники');
boxplot.set_ylabel('Время');
plt.xticks(rotation=90)
boxplot.grid()

# %%
fig = plt.figure(figsize=(20, 7))
boxplot = sns.barplot(
    data=hours_df,
    y= 'Exit_cnt',
    x= 'Month',
    hue='Gender'
    #width=0.9
)
boxplot.set_title('Среднее количество выходов из офиса по месяцам');
boxplot.set_xlabel('2022 год');
boxplot.set_ylabel('Количество выходов ');
boxplot.set_xticklabels(['Июль', 'Август', 'Сентябрь', 'Октябрь', 'Ноябрь', 'Декабрь'])
plt.xticks(rotation=0)
boxplot.grid()

# %% [markdown]
# Присоединим заранее обработанную таблицу с количеством заявок на каждого сотрудника по дням

# %%
sd_df = pd.read_excel('SD_tasks_count.xlsx', index_col=0)
sd_df.head()
# Out:
#         Date     Employee  Tasks_cnt
# 0 2022-07-01  Галлямов А.          1
# 1 2022-07-01    Хижняк П.          2
# 2 2022-07-01   Зацепин Д.          3
# 3 2022-07-01  Ляпунова Н.          2
# 4 2022-07-01   Пинегин Е.          1

# %%
sd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1394 entries, 0 to 1787
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1394 non-null   datetime64[ns]
#  1   Employee   1394 non-null   object
#  2   Tasks_cnt  1394 non-null   int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 43.6+ KB

# %%
tasks = sd_df[['Employee', 'Tasks_cnt']].groupby('Employee').agg('mean').sort_values(by='Tasks_cnt', ascending=False)

# %%
fig = plt.figure(figsize=(20, 7))
boxplot = sns.barplot(
    data=sd_df,
    y= 'Tasks_cnt',
    x= 'Employee',
    order=tasks.index
    #hue='Gender'
    #width=0.9
)
boxplot.set_title('Среднее количество отработанных заявок в день');
boxplot.set_xlabel('2022 год');
boxplot.set_ylabel('Количество заявок ');
#boxplot.set_xticklabels(['Июль', 'Август', 'Сентябрь', 'Октябрь', 'Ноябрь', 'Декабрь'])
plt.xticks(rotation=90)
boxplot.grid()

# %% [markdown]
# Объединяем имеющиеся таблицы по полям Дата и Сотрудники

# %%
merged_df = pd.merge(hours_df, sd_df, how='left', left_on=['Day', 'Employee'], right_on=['Date', 'Employee'])
merged_df.head()
# Out:
#          Day         Employee  Gender First_enter_time Last_exit_time  \
# 0 2022-07-01     Понамарёв Н.    Male         07:49:00       18:12:00
# 1 2022-07-01  Баймолданова А.  Female         08:35:00       18:07:00
# 2 2022-07-01     Камбарова М.  Female         08:39:00       17:37:00
# 3 2022-07-01       Садыков А.    Male         08:43:00       18:16:00
# 4 2022-07-01      Путейчев В.    Male         08:48:00       18:09:00
#
#    Late_min  Early_exit  Exit_cnt  Timedelta_hour  Month       Date  Tasks_cnt
# 0       0.0         0.0      14.0            7.95      7        NaT        NaN
# 1       0.0         0.0       3.0            8.30      7        NaT        NaN
# 2       9.0         0.0       2.0            7.68      7 2022-07-01        2.0
# 3       0.0         0.0       3.0            8.28      7        NaT        NaN
# 4       0.0         0.0       2.0            8.35      7        NaT        NaN

# %%
fig = plt.figure(figsize=(20, 10))
scatterplot = sns.scatterplot(
    data=merged_df,
    y= 'Tasks_cnt',
    x= 'Timedelta_hour',
    #order=tasks.index
    hue='Gender'
    #width=0.9
)
scatterplot.set_title('Отношение количества отработанных заявок к времени проведенному в офисе сотрудником');
scatterplot.set_xlabel('Часы');
scatterplot.set_ylabel('Количество заявок ');
plt.xticks(rotation=0)
scatterplot.grid()

# %% [markdown]
# Рассмотрим случаи когда количество заявок превысило 25 в день, и среди них есть случаи нахождения в офисе составляет 0 часов

# %%
merged_df[merged_df['Tasks_cnt']>25]
# Out:
#            Day       Employee  Gender First_enter_time Last_exit_time  \
# 319 2022-07-22  Мурумбаева Г.  Female         08:57:00       18:09:00
# 430 2022-07-29  Есенжарулы Д.    Male         08:49:00       17:55:00
# 572 2022-08-09  Есенжарулы Д.    Male         13:48:00       13:54:00
# 640 2022-08-12  Есенжарулы Д.    Male         13:31:00       13:57:00
# 667 2022-08-15  Есенжарулы Д.    Male         08:50:00       18:35:00
# 722 2022-08-17  Есенжарулы Д.    Male         08:44:00       18:07:00
#
#      Late_min  Early_exit  Exit_cnt  Timedelta_hour  Month       Date  \
# 319       0.0         0.0       2.0            8.07      7 2022-07-22
# 430       0.0         5.0       2.0            7.88      7 2022-07-29
# 572       0.0         0.0       1.0            0.00      8 2022-08-09
# 640       0.0         0.0       1.0            0.00      8 2022-08-12
# 667       0.0         0.0       1.0            8.75      8 2022-08-15
# 722       0.0         0.0       1.0            8.38      8 2022-08-17
#
#      Tasks_cnt
# 319       32.0
# 430       28.0
# 572       28.0
# 640       27.0
# 667       29.0
# 722       33.0

# %% [markdown]
# Посмотрим кто у нас находился в офисе менее 2 часов но при этом исполнил 1 заявку

# %%
merged_df[(merged_df['Tasks_cnt']==1)&(merged_df['Timedelta_hour']<2)]
# Out:
#             Day       Employee Gender First_enter_time Last_exit_time  \
# 95   2022-07-07     Зацепин Д.   Male         14:58:00       15:05:00
# 153  2022-07-12    Медведев И.   Male         17:26:00       18:37:00
# 227  2022-07-15     Зацепин Д.   Male         11:04:00       11:09:00
# 429  2022-07-29    Галлямов А.   Male         10:17:00       10:20:00
# 991  2022-09-02    Печенкин Р.   Male         14:41:00       14:49:00
# 993  2022-09-02    Галлямов А.   Male         14:41:00       14:56:00
# 1015 2022-09-05    Медведев И.   Male         09:07:00       18:35:00
# 1031 2022-09-05  Максимович Е.   Male         14:03:00       14:08:00
# 1061 2022-09-06      Хижняк П.   Male         11:44:00       11:58:00
# 1078 2022-09-07    Медведев И.   Male         17:36:00       18:39:00
# 1619 2022-10-04    Медведев И.   Male         16:23:00       18:07:00
# 1952 2022-10-20     Радичев С.   Male         09:00:00       10:33:00
# 2447 2022-11-17    Медведев И.   Male         09:09:00       11:00:00
# 2452 2022-11-17     Радичев С.   Male         09:01:00       09:29:00
# 2855 2022-12-13     Радичев С.   Male         09:04:00       09:09:00
#
#       Late_min  Early_exit  Exit_cnt  Timedelta_hour  Month       Date  \
# 95         0.0         0.0       1.0            0.12      7 2022-07-07
# 153        0.0         0.0       1.0            1.18      7 2022-07-12
# 227        0.0         0.0       1.0            0.08      7 2022-07-15
# 429        0.0         0.0       1.0            0.05      7 2022-07-29
# 991        0.0         0.0       1.0            0.13      9 2022-09-02
# 993        0.0         0.0       1.0            0.25      9 2022-09-02
# 1015       7.0         0.0       2.0            1.67      9 2022-09-05
# 1031       0.0         0.0       1.0            0.08      9 2022-09-05
# 1061       0.0         0.0       1.0            0.23      9 2022-09-06
# 1078       0.0         0.0       1.0            1.05      9 2022-09-07
# 1619       0.0         0.0       1.0            1.73     10 2022-10-04
# 1952       0.0         0.0       1.0            1.55     10 2022-10-20
# 2447       9.0         0.0       1.0            1.85     11 2022-11-17
# 2452       1.0         0.0       1.0            0.47     11 2022-11-17
# 2855       4.0         0.0       1.0            0.08     12 2022-12-13
#
#       Tasks_cnt
# 95          1.0
# 153         1.0
# 227         1.0
# 429         1.0
# 991         1.0
# 993         1.0
# 1015        1.0
# 1031        1.0
# 1061        1.0
# 1078        1.0
# 1619        1.0
# 1952        1.0
# 2447        1.0
# 2452        1.0
# 2855        1.0
